# %%
from google.colab import drive

# %%
#mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
datapath=('/content/drive/MyDrive/matches_1930_2022.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv(datapath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
filtereddata = df['home_team'].value_counts()

# %%
f2=filtereddata[filtereddata >=40].index

# %%
f2
# Out:
# Index(['Brazil', 'Argentina', 'Italy', 'England', 'Germany'], dtype='object', name='home_team')

# %%
df2=df[df["home_team"].isin(f2)]

# %%
df2
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 3    Argentina         Croatia           3      2.3           NaN           0
# 5      England          France           1      2.4           NaN           2
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 13     England         Senegal           3      1.0           NaN           0
# ..         ...             ...         ...      ...           ...         ...
# 948  Argentina   United States           6      NaN           NaN           1
# 949  Argentina           Chile           3      NaN           NaN           1
# 951     Brazil         Bolivia           4      NaN           NaN           0
# 954  Argentina          Mexico           6      NaN           NaN           3
# 959  Argentina          France           1      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager     home_captain  ...  \
# 0        2.2           2.0       Lionel Scaloni     Lionel Messi  ...
# 3        0.5           NaN       Lionel Scaloni     Lionel Messi  ...
# 5        0.9           NaN     Gareth Southgate       Harry Kane  ...
# 11       0.5           NaN                 Tite     Thiago Silva  ...
# 13       0.8           NaN     Gareth Southgate       Harry Kane  ...
# ..       ...           ...                  ...              ...  ...
# 948      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 949      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 951      NaN           NaN  Pindaro De Carvalho        Preguinho  ...
# 954      NaN           NaN     Francisco Olazar     Ángel Bossio  ...
# 959      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 3                               NaN
# 5                               NaN
# 11                              NaN
# 13                              NaN
# ..                              ...
# 948                             NaN
# 949                             NaN
# 951                             NaN
# 954                             NaN
# 959                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 3                                                  NaN            NaN
# 5                                                  NaN            NaN
# 11                                                 NaN            NaN
# 13                                                 NaN            NaN
# ..                                                 ...            ...
# 948                                                NaN            NaN
# 949                                                NaN            NaN
# 951                                                NaN            NaN
# 954                                                NaN            NaN
# 959                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 3             NaN                  NaN                  NaN
# 5             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 13            NaN                  NaN                  NaN
# ..            ...                  ...                  ...
# 948           NaN                  NaN                  NaN
# 949           NaN                  NaN                  NaN
# 951           NaN                  NaN                  NaN
# 954           NaN                  NaN                  NaN
# 959           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 5                     ['90&rsquor;|1:2|Harry Maguire']
# 11                                                 NaN
# 13                                                 NaN
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 5    ['43&rsquor;|0:1|Antoine Griezmann', '47&rsquo...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 13                ['76&rsquor;|3:0|Kalidou Koulibaly']
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 5    ['79&rsquor;|1:2|Raheem Sterling|for Bukayo Sa...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 13   ['65&rsquor;|3:0|Jack Grealish|for Phil Foden'...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 5    ['79&rsquor;|1:2|Kingsley Coman|for Ousmane De...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 13   ['46&rsquor;|2:0|Pape Matar Sarr|for Krépin Di...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
# [281 rows x 44 columns]

# %%
df2["home_xg"].value_counts()
# Out:
# home_xg
# 2.2    2
# 2.4    2
# 1.0    2
# 1.4    2
# 2.8    2
# 2.1    1
# 1.3    1
# 2.6    1
# 0.9    1
# 2.7    1
# 3.3    1
# 2.3    1
# 3.1    1
# 0.8    1
# 0.3    1
# 1.6    1
# 3.6    1
# 1.9    1
# Name: count, dtype: int64

# %%
# %matplotlib inline

# %%
df2.plot(x='home_team',y='home_xg',kind='bar')
# Out:
# <Axes: xlabel='home_team'>

# %%
f3 = df2["home_xg"]>2.5

# %%
df3=df2[f3]

# %%
f3
# Out:
# 0       True
# 3      False
# 5      False
# 11      True
# 13     False
#        ...
# 948    False
# 949    False
# 951    False
# 954    False
# 959    False
# Name: home_xg, Length: 281, dtype: bool

# %%
from matplotlib import pyplot as plt

# %%
df3.plot(x="home_team",y="home_xg",kind="bar")
plt.xlabel("Home Team")
plt.ylabel("Home XG")
plt.title("Home Teams estimated goals")
plt.show()

# %%
df3.plot(x="home_team",y="home_xg",kind="pie")
plt.xlabel("Home Team")
plt.ylabel("Home XG")
plt.title("Home Teams estimated goals")
plt.show()

# %%
df3.plot(x="home_team",y="home_xg",kind="barh")
plt.xlabel("Home Team")
plt.ylabel("Home XG")
plt.title("Home Teams estimated goals")
plt.show()

# %%
df3.plot(x="home_team",y="home_xg",kind="scatter")
plt.xlabel("Home Team")
plt.ylabel("Home XG")
plt.title("Home Teams estimated goals")
plt.show()

# %%
df3.plot(x="home_team",y="home_xg",kind="box")
plt.xlabel("Home Team")
plt.ylabel("Home XG")
plt.title("Home Teams estimated goals")
plt.show()

# %%
df3
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 53     Germany           Japan           1      3.1           NaN           2
# 71      Brazil         Belgium           1      2.8           NaN           2
# 74      Brazil          Mexico           2      2.7           NaN           0
# 96     England          Panama           6      2.8           NaN           1
# 102     Brazil      Costa Rica           2      2.6           NaN           0
#
#      away_xg  away_penalty      home_manager  home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni  Lionel Messi  ...
# 11       0.5           NaN              Tite  Thiago Silva  ...
# 53       1.5           NaN       Hansi Flick  Manuel Neuer  ...
# 71       0.5           NaN              Tite       Miranda  ...
# 74       0.7           NaN              Tite  Thiago Silva  ...
# 96       1.1           NaN  Gareth Southgate    Harry Kane  ...
# 102      0.1           NaN              Tite  Thiago Silva  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 11                              NaN
# 53                              NaN
# 71                              NaN
# 74                              NaN
# 96                              NaN
# 102                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 11                                                 NaN            NaN
# 53                                                 NaN            NaN
# 71                                                 NaN            NaN
# 74                                                 NaN            NaN
# 96                                                 NaN            NaN
# 102                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 53            NaN                  NaN                  NaN
# 71            NaN                  NaN                  NaN
# 74            NaN                  NaN                  NaN
# 96            NaN                  NaN                  NaN
# 102           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 11                                                 NaN
# 53                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# 96               ['23&rsquor;|2:0|Ruben Loftus-Cheek']
# 102  ['81&rsquor;|0:0|Philippe Coutinho', '81&rsquo...
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 53                                                 NaN
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# 96   ['10&rsquor;|1:0|Armando Cooper', '44&rsquor;|...
# 102                   ['84&rsquor;|0:0|Johnny Acosta']
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 53   ['67&rsquor;|1:0|Jonas Hofmann|for Thomas Müll...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# 96   ['63&rsquor;|6:0|Jamie Vardy|for Harry Kane', ...
# 102  ['46&rsquor;|0:0|Douglas Costa|for Willian', '...
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 53   ['46&rsquor;|1:0|Takehiro Tomiyasu|for Takefus...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# 96   ['62&rsquor;|5:0|Ricardo Ávila|for Aníbal Godo...
# 102  ['54&rsquor;|0:0|Christian Bolaños|for Marco U...
#
# [7 rows x 44 columns]

# %%
df3.plot(x="home_team",y= ['home_score','home_xg'],kind="bar",color=["green","red"])
plt.xlabel("Home Team")
plt.ylabel("Home XG")
plt.title("Home Teams estimated goals")
plt.show()

# %%
df3.plot(x="home_team",y= ['home_score','home_xg'],kind="bar")
plt.xlabel("Home Team")
plt.ylabel("Home XG")
plt.title("Home Teams estimated goals")
plt.show()

# %%
df3.plot(x="home_team",y= ['home_score','home_xg'],kind="barh",color=["green","red"])
plt.xlabel("Home Team")
plt.ylabel("Home XG")
plt.title("Home Teams estimated goals")
plt.show()

# %%
df.groupby("home_team")["home_score"].mean()
# Out:
# home_team
# Algeria         0.833333
# Angola          0.000000
# Argentina       2.050847
# Australia       1.000000
# Austria         2.000000
#                   ...
# Uruguay         2.060606
# Wales           0.666667
# West Germany    2.026316
# Yugoslavia      2.562500
# Zaire           0.000000
# Name: home_score, Length: 82, dtype: float64

# %%
df.describe()
# Out:
#        home_score     home_xg  home_penalty  away_score     away_xg  \
# count  964.000000  128.000000     35.000000  964.000000  128.000000
# mean     1.776971    1.435938      3.285714    1.044606    1.192187
# std      1.596676    0.860391      1.226459    1.071233    0.809258
# min      0.000000    0.100000      0.000000    0.000000    0.000000
# 25%      1.000000    0.800000      3.000000    0.000000    0.600000
# 50%      1.000000    1.300000      3.000000    1.000000    1.000000
# 75%      3.000000    1.925000      4.000000    2.000000    1.525000
# max     10.000000    5.200000      5.000000    7.000000    5.700000
#
#        away_penalty     Attendance         Year
# count     35.000000     964.000000   964.000000
# mean       3.057143   45693.374481  1989.244813
# std        1.136115   22704.131689    24.014409
# min        0.000000    2000.000000  1930.000000
# 25%        2.000000   31800.000000  1974.000000
# 50%        3.000000   42725.000000  1994.000000
# 75%        4.000000   60984.500000  2010.000000
# max        5.000000  173850.000000  2022.000000

# %%
dg = df.groupby("home_team")["home_xg"]

# %%
print(dg.mean())
# Out:
# home_team
# Algeria              NaN
# Angola               NaN
# Argentina       1.842857
# Australia       0.750000
# Austria              NaN
#                   ...
# Uruguay         1.240000
# Wales           0.600000
# West Germany         NaN
# Yugoslavia           NaN
# Zaire                NaN
# Name: home_xg, Length: 82, dtype: float64

# %%
das = pd.DataFrame({
    'Branch':['B.COM','ECE','CSE','BBA','BCA'],
    'Name':['rohit','suresh','Avi','ram','krishna'],
    'Salary':[21000,20000,16000,15000,13000],
})

# %%
das
# Out:
#   Branch     Name  Salary
# 0    CSE    rohit   21000
# 1    ECE   suresh   20000
# 2    CSE      Avi   16000
# 3    BBA      ram   15000
# 4    BCA  krishna   13000

# %%
sv = das.groupby('Branch')['Salary']

# %%
das.describe()
# Out:
#              Salary
# count      5.000000
# mean   17000.000000
# std     3391.164992
# min    13000.000000
# 25%    15000.000000
# 50%    16000.000000
# 75%    20000.000000
# max    21000.000000

# %%
sv.agg(['mean','min'])
# Out:
#            mean    min
# Branch
# B.COM   21000.0  21000
# BBA     15000.0  15000
# BCA     13000.0  13000
# CSE     16000.0  16000
# ECE     20000.0  20000

# %%
sv2= das.groupby(['Branch','Name'])['Salary']

# %%
sv2.max()
# Out:
# Branch  Name
# B.COM   rohit      21000
# BBA     ram        15000
# BCA     krishna    13000
# CSE     Avi        16000
# ECE     suresh     20000
# Name: Salary, dtype: int64

# %%
sv2.min()
# Out:
# Branch  Name
# B.COM   rohit      21000
# BBA     ram        15000
# BCA     krishna    13000
# CSE     Avi        16000
# ECE     suresh     20000
# Name: Salary, dtype: int64

# %%
sv2.mean()
# Out:
# Branch  Name
# B.COM   rohit      21000.0
# BBA     ram        15000.0
# BCA     krishna    13000.0
# CSE     Avi        16000.0
# ECE     suresh     20000.0
# Name: Salary, dtype: float64

# %%
sv2.std()
# Out:
# Branch  Name
# B.COM   rohit     NaN
# BBA     ram       NaN
# BCA     krishna   NaN
# CSE     Avi       NaN
# ECE     suresh    NaN
# Name: Salary, dtype: float64

# %%
sv2.count()
# Out:
# Branch  Name
# B.COM   rohit      1
# BBA     ram        1
# BCA     krishna    1
# CSE     Avi        1
# ECE     suresh     1
# Name: Salary, dtype: int64

# %%
import random

# %%
age=[]
height=[]
weight=[]

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df.shape
# Out:
# (964, 44)

# %%
#loop compressions
[age.append(random.randint(18,40))for _ in range(964)]
print(f"Age is now having {len(age)}")
# Out:
# Age is now having 964

# %%
age
# Out:
# [26,
#  18,
#  20,
#  19,
#  23,
#  32,
#  40,
#  39,
#  30,
#  19,
#  28,
#  29,
#  37,
#  32,
#  34,
#  21,
#  40,
#  20,
#  40,
#  27,
#  38,
#  28,
#  31,
#  32,
#  23,
#  18,
#  29,
#  34,
#  26,
#  28,
#  28,
#  19,
#  22,
#  28,
#  36,
#  35,
#  25,
#  28,
#  35,
#  22,
#  38,
#  19,
#  28,
#  26,
#  25,
#  29,
#  27,
#  35,
#  36,
#  22,
#  38,
#  21,
#  20,
#  40,
#  33,
#  35,
#  22,
#  30,
#  40,
#  24,
#  24,
#  24,
#  23,
#  29,
#  26,
#  19,
#  21,
#  31,
#  28,
#  31,
#  22,
#  28,
#  23,
#  24,
#  34,
#  22,
#  31,
#  36,
#  23,
#  21,
#  38,
#  36,
#  38,
#  25,
#  36,
#  37,
#  36,
#  39,
#  35,
#  22,
#  34,
#  19,
#  28,
#  20,
#  30,
#  21,
#  19,
#  26,
#  40,
#  38,
#  35,
#  35,
#  23,
#  24,
#  27,
#  21,
#  26,
#  27,
#  32,
#  24,
#  29,
#  20,
#  36,
#  28,
#  30,
#  38,
#  29,
#  35,
#  29,
#  21,
#  25,
#  23,
#  31,
#  20,
#  34,
#  38,
#  19,
#  18,
#  39,
#  38,
#  35,
#  21,
#  27,
#  36,
#  34,
#  37,
#  19,
#  19,
#  30,
#  29,
#  28,
#  20,
#  30,
#  38,
#  20,
#  30,
#  20,
#  33,
#  28,
#  37,
#  35,
#  39,
#  30,
#  40,
#  29,
#  38,
#  34,
#  36,
#  32,
#  33,
#  28,
#  24,
#  27,
#  25,
#  19,
#  35,
#  38,
#  35,
#  35,
#  39,
#  20,
#  22,
#  30,
#  30,
#  22,
#  33,
#  30,
#  19,
#  28,
#  21,
#  40,
#  37,
#  40,
#  35,
#  32,
#  33,
#  31,
#  18,
#  29,
#  33,
#  23,
#  26,
#  31,
#  40,
#  24,
#  26,
#  33,
#  33,
#  40,
#  26,
#  38,
#  29,
#  37,
#  36,
#  37,
#  29,
#  27,
#  31,
#  32,
#  35,
#  36,
#  40,
#  33,
#  36,
#  22,
#  33,
#  36,
#  31,
#  29,
#  27,
#  38,
#  26,
#  19,
#  27,
#  40,
#  19,
#  21,
#  28,
#  38,
#  18,
#  24,
#  34,
#  19,
#  32,
#  21,
#  18,
#  39,
#  31,
#  20,
#  32,
#  25,
#  38,
#  18,
#  35,
#  30,
#  29,
#  24,
#  34,
#  22,
#  34,
#  21,
#  30,
#  18,
#  32,
#  18,
#  23,
#  31,
#  26,
#  34,
#  23,
#  38,
#  18,
#  33,
#  20,
#  32,
#  35,
#  26,
#  33,
#  21,
#  26,
#  34,
#  33,
#  22,
#  21,
#  19,
#  33,
#  27,
#  29,
#  28,
#  21,
#  20,
#  36,
#  36,
#  37,
#  18,
#  37,
#  29,
#  35,
#  29,
#  26,
#  18,
#  22,
#  24,
#  26,
#  33,
#  38,
#  20,
#  21,
#  38,
#  22,
#  35,
#  39,
#  37,
#  35,
#  21,
#  35,
#  18,
#  30,
#  33,
#  24,
#  31,
#  31,
#  18,
#  39,
#  18,
#  37,
#  31,
#  36,
#  20,
#  21,
#  39,
#  25,
#  26,
#  38,
#  21,
#  28,
#  32,
#  18,
#  27,
#  21,
#  38,
#  30,
#  27,
#  20,
#  22,
#  20,
#  18,
#  27,
#  20,
#  37,
#  34,
#  28,
#  21,
#  26,
#  27,
#  21,
#  33,
#  38,
#  36,
#  21,
#  26,
#  30,
#  22,
#  37,
#  25,
#  34,
#  18,
#  18,
#  36,
#  24,
#  40,
#  25,
#  32,
#  38,
#  23,
#  34,
#  38,
#  35,
#  20,
#  20,
#  36,
#  23,
#  38,
#  40,
#  40,
#  21,
#  32,
#  31,
#  21,
#  35,
#  20,
#  26,
#  20,
#  24,
#  33,
#  35,
#  39,
#  33,
#  25,
#  38,
#  27,
#  25,
#  40,
#  18,
#  29,
#  36,
#  21,
#  35,
#  40,
#  25,
#  38,
#  30,
#  21,
#  19,
#  35,
#  27,
#  40,
#  25,
#  18,
#  38,
#  40,
#  37,
#  30,
#  31,
#  35,
#  40,
#  29,
#  21,
#  31,
#  34,
#  40,
#  25,
#  21,
#  33,
#  18,
#  28,
#  36,
#  20,
#  30,
#  23,
#  39,
#  39,
#  34,
#  24,
#  27,
#  31,
#  20,
#  18,
#  35,
#  19,
#  32,
#  25,
#  26,
#  40,
#  27,
#  32,
#  31,
#  33,
#  27,
#  32,
#  27,
#  23,
#  34,
#  37,
#  25,
#  32,
#  18,
#  24,
#  24,
#  23,
#  21,
#  21,
#  30,
#  27,
#  36,
#  33,
#  36,
#  28,
#  40,
#  24,
#  38,
#  28,
#  39,
#  22,
#  23,
#  37,
#  35,
#  36,
#  22,
#  34,
#  33,
#  28,
#  25,
#  24,
#  30,
#  25,
#  33,
#  32,
#  36,
#  33,
#  18,
#  27,
#  32,
#  26,
#  33,
#  36,
#  34,
#  32,
#  34,
#  23,
#  30,
#  37,
#  22,
#  24,
#  28,
#  26,
#  23,
#  34,
#  29,
#  33,
#  37,
#  20,
#  34,
#  22,
#  38,
#  32,
#  34,
#  24,
#  31,
#  31,
#  18,
#  20,
#  31,
#  20,
#  29,
#  22,
#  22,
#  21,
#  38,
#  19,
#  39,
#  25,
#  26,
#  37,
#  36,
#  37,
#  27,
#  25,
#  30,
#  31,
#  34,
#  40,
#  21,
#  18,
#  38,
#  26,
#  24,
#  31,
#  35,
#  36,
#  35,
#  38,
#  40,
#  31,
#  25,
#  33,
#  34,
#  35,
#  26,
#  35,
#  37,
#  26,
#  23,
#  38,
#  29,
#  33,
#  33,
#  38,
#  37,
#  27,
#  34,
#  37,
#  20,
#  39,
#  23,
#  34,
#  40,
#  19,
#  33,
#  26,
#  32,
#  27,
#  21,
#  20,
#  35,
#  18,
#  19,
#  37,
#  22,
#  29,
#  30,
#  28,
#  36,
#  31,
#  31,
#  18,
#  30,
#  26,
#  33,
#  40,
#  20,
#  30,
#  20,
#  19,
#  32,
#  25,
#  30,
#  21,
#  24,
#  26,
#  37,
#  40,
#  35,
#  26,
#  31,
#  24,
#  35,
#  29,
#  39,
#  23,
#  24,
#  21,
#  35,
#  19,
#  31,
#  20,
#  32,
#  40,
#  18,
#  32,
#  39,
#  26,
#  39,
#  30,
#  18,
#  39,
#  38,
#  23,
#  31,
#  19,
#  36,
#  40,
#  35,
#  22,
#  23,
#  19,
#  25,
#  20,
#  36,
#  18,
#  37,
#  30,
#  22,
#  27,
#  18,
#  23,
#  27,
#  40,
#  33,
#  28,
#  31,
#  21,
#  24,
#  28,
#  26,
#  36,
#  28,
#  21,
#  40,
#  32,
#  35,
#  37,
#  27,
#  38,
#  27,
#  34,
#  28,
#  28,
#  32,
#  20,
#  36,
#  38,
#  27,
#  18,
#  29,
#  22,
#  26,
#  28,
#  19,
#  35,
#  36,
#  20,
#  33,
#  21,
#  26,
#  39,
#  24,
#  36,
#  23,
#  38,
#  35,
#  26,
#  33,
#  20,
#  32,
#  23,
#  21,
#  21,
#  30,
#  18,
#  36,
#  20,
#  26,
#  33,
#  26,
#  20,
#  30,
#  26,
#  18,
#  40,
#  28,
#  32,
#  24,
#  21,
#  22,
#  19,
#  40,
#  34,
#  25,
#  22,
#  24,
#  34,
#  31,
#  32,
#  35,
#  21,
#  18,
#  38,
#  26,
#  26,
#  20,
#  21,
#  39,
#  21,
#  23,
#  38,
#  24,
#  40,
#  28,
#  24,
#  31,
#  30,
#  27,
#  40,
#  32,
#  20,
#  22,
#  32,
#  21,
#  26,
#  24,
#  34,
#  18,
#  21,
#  38,
#  38,
#  26,
#  20,
#  22,
#  38,
#  18,
#  23,
#  28,
#  35,
#  31,
#  36,
#  29,
#  30,
#  26,
#  33,
#  19,
#  37,
#  21,
#  32,
#  28,
#  40,
#  33,
#  32,
#  26,
#  25,
#  36,
#  39,
#  31,
#  38,
#  32,
#  21,
#  34,
#  22,
#  36,
#  40,
#  28,
#  40,
#  23,
#  18,
#  40,
#  40,
#  36,
#  31,
#  24,
#  22,
#  20,
#  21,
#  24,
#  40,
#  39,
#  36,
#  31,
#  18,
#  30,
#  33,
#  26,
#  24,
#  32,
#  33,
#  30,
#  21,
#  30,
#  36,
#  19,
#  37,
#  30,
#  39,
#  37,
#  31,
#  25,
#  34,
#  31,
#  37,
#  38,
#  38,
#  33,
#  22,
#  21,
#  39,
#  28,
#  37,
#  32,
#  36,
#  24,
#  34,
#  38,
#  23,
#  22,
#  33,
#  37,
#  29,
#  37,
#  39,
#  34,
#  36,
#  23,
#  26,
#  19,
#  20,
#  20,
#  33,
#  29,
#  28,
#  25,
#  22,
#  28,
#  23,
#  38,
#  19,
#  39,
#  27,
#  33,
#  33,
#  27,
#  35,
#  39,
#  19,
#  29,
#  22,
#  23,
#  31,
#  29,
#  19,
#  21,
#  39,
#  19,
#  38,
#  23,
#  33,
#  38,
#  33,
#  39,
#  23,
#  19,
#  38,
#  37,
#  27,
#  33,
#  35,
#  26,
#  24,
#  33,
#  21,
#  25,
#  31,
#  23,
#  34,
#  22,
#  29,
#  35,
#  27,
#  39,
#  38,
#  27,
#  29,
#  25,
#  31,
#  25,
#  32,
#  29,
#  37,
#  29,
#  40,
#  19,
#  40,
#  25,
#  35,
#  23,
#  40,
#  18,
#  26,
#  30,
#  26,
#  35,
#  40,
#  24,
#  18,
#  37,
#  28,
#  32,
#  28,
#  24,
#  40,
#  31,
#  39,
#  39,
#  38,
#  39,
#  40,
#  38,
#  38,
#  40,
#  30,
#  19,
#  32,
#  30,
#  37,
#  18,
#  33]

# %%
#Adding a new column to Dframe
#syntax:df['newcolumncolumn']=list/series.....

# %%
df['yearofexperience']=age

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#                        away_penalty_shootout_miss_long home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 959                                                NaN           NaN
# 960                                                NaN           NaN
# 961                                                NaN           NaN
# 962                                                NaN           NaN
# 963                                                NaN           NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long yearofexperience
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...               26
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...               18
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...               20
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...               19
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...               23
# ..                                                 ...              ...
# 959                                                NaN               32
# 960                                                NaN               30
# 961                                                NaN               37
# 962                                                NaN               18
# 963                                                NaN               33
#
# [964 rows x 45 columns]

# %%
df['ASP']=df['yearofexperience']-df['home_score']

# %%
df.shape
# Out:
# (964, 46)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_red_card         away_red_card   home_yellow_red_card  \
# 0             NaN                   NaN                    NaN
# 1             NaN                   NaN                    NaN
# 2             NaN                   NaN                    NaN
# 3             NaN                   NaN                    NaN
# 4             NaN                   NaN  Walid Cheddira · 90+3
# ..            ...                   ...                    ...
# 959           NaN                   NaN                    NaN
# 960           NaN                   NaN                    NaN
# 961           NaN  Plácido Galindo · 70                    NaN
# 962           NaN                   NaN                    NaN
# 963           NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 0                    NaN  ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long yearofexperience ASP
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...               26  23
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...               18  16
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...               20  18
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...               19  16
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...               23  22
# ..                                                 ...              ...  ..
# 959                                                NaN               32  31
# 960                                                NaN               30  28
# 961                                                NaN               37  34
# 962                                                NaN               18  15
# 963                                                NaN               33  29
#
# [964 rows x 46 columns]

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df.plot(x='yearofexperience',y=['ASP','home_score'],kind='bar', color=['green','red'])
# Out:
# <Axes: xlabel='yearofexperience'>

# %%
df.plot(x='yearofexperience',y=['away_score','home_score'],kind='bar', color=['green','red'])
# Out:
# <Axes: xlabel='yearofexperience'>

# %%
df.plot(x='yearofexperience',y='home_score',kind='pie')
# Out:
# <Axes: ylabel='home_score'>

# %%
# Function to get a graph
def getGraph(Dataframe, column1 , column2):
  from matplotlib import pyplot as plt

  #Check the length of column1 and column2
  if len(Dataframe[column1]) == len(Dataframe[column2]):
     df.plot(x = column1, y = column2, kind = 'bar', color = ['blue','pink'])
     print('The graph/plot is succesfully created')

  else :
       print('Please check the column size once')

# %%
getGraph(df, 'home_score','away_score')
# Out:
# The graph/plot is succesfully created
